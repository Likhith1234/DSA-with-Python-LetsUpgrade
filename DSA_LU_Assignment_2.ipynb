# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhith1234/DSA-with-Python-LetsUpgrade/blob/main/DSA_LU_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find the time complexity of the following Pseudo Code
# for( i = 1 ; i <= n ; i = i*2)
# for( j = 1 ; j <= i ; j++)
# print(“Hello”)

# %% [markdown]
# Answer is O(n)![img.jpeg](data:image/jpeg;base64,...)
